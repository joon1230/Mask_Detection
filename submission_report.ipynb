# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
res = pd.read_csv("../input/data/eval/##BEST##43th_ensemble.csv")

# %%
res.head()
# Out:
#    Unnamed: 0                                       ImageID  ans
# 0           0  cbc5c6e168e63498590db46022617123f1fe1268.jpg   13
# 1           1  0e72482bf56b3581c081f7da2a6180b8792c7089.jpg    2
# 2           2  b549040c49190cedc41327748aeb197c1670f14d.jpg   13
# 3           3  4f9cb2a045c6d5b9e50ad3459ea7b791eb6e18bc.jpg   13
# 4           4  248428d9a4a5b6229a7081c32851b90cb8d38d0c.jpg   12

# %%
tmp = res.ans.value_counts()
print('best')
sns.barplot(x=tmp.index, y=tmp.values)
# Out:
# best

# %%
def count_labels(path):
    res = pd.read_csv(path)
    tmp = res.ans.value_counts()
    sns.barplot(x=tmp.index, y=tmp.values)
    plt.show()

# %%
print('uniform_dist_40th')
count_labels('../input/data/eval/40th_EfficientNet_b2500300_train_0.8_ver12_uniformdist_epoch_7.csv')
# Out:
# uniform_dist_40th

# %%
print('best2')
count_labels("../input/data/eval/##BEST2##13&26th_submission_ResNet34_oversampling_36.csv")
# Out:
# best2

# %%
print('best3')
count_labels("../input/data/eval/##BEST3##23th_EfficientNet_b2oversample_size_400300_loss_label_weight_totaltwo_14.csv")
# Out:
# best3

# %%
print('best4')
count_labels("../input/data/eval/##BEST4##8th_submission_Inception_size224_31.csv")
# Out:
# best4

# %%
print('14th sub')
count_labels("../input/data/eval/14th_submission_Inception_size224_oversampling_29.csv")
# Out:
# 14th sub

# %%
print('38th sub')
count_labels("../input/data/eval/38th_EfficientNet_b2500300_train_0.8_ver10_pixblur.csv")
# Out:
# 38th sub

# %%
print('43th sub')
count_labels("../input/data/eval/##BEST##43th_ensemble.csv")
# Out:
# 43th sub

# %%
print('44th sub')
count_labels("../input/data/eval/44thResNet50500300_train_0.8_ver16epoch_3.csv")
# Out:
# 44th sub

# %%
print('56th sub')
count_labels("../input/data/eval/56th_EfficientNet_b4350350_train_0.8_ver22epoch_15.csv")
# Out:
# 56th sub

# %%
'##BEST2##42thEfficientNet_b2500300_train_0.4_ver14_LowTrainRatio/epoch_15.csv',
'##BEST3##28th_EfficientNet_b2oversample_size_500300_loss_label_weight_/epoch_20.csv'
'##BEST4##13&26th_submission_ResNet34_oversampling_36.csv'
'##BEST5##23th_EfficientNet_b2oversample_size_400300_loss_label_weight_totaltwo/epoch14.csv'
 '38th_EfficientNet_b2500300_train_0.8_ver10_pixblur.csv'
 '47th_EfficientNet_b2400300_train_0.7_ver17/epoch_8.csv'
'##BEST5##8th_submission_Inception_size224_31.csv'
'53th_EfficientNet_b2350350_train_0.8_ver20epoch_11'
'49th_EfficientNet_b4500300_train_0.7_augmentationepoch_12'

# %%
import os, glob
base_path = "../input/data/eval/*.csv"
res = glob.glob(base_path)
for f in [i for i in res if not('info.csv' in i )]:
    print(f.split('/')[-1])
    count_labels(f)
# Out:
# 44thResNet50500300_train_0.8_ver16epoch_3.csv
# tt_submission.csv
# 39th_EfficientNet_b2500300_train_0.8_ver11_pixtransform_epoch_8.csv
# submission_ResNet34_2.csv
# 10th_submission_Incepetion_size_224_Adamp_35.csv
# 12th_submission_Inception_Adamp_24.csv
# submission_ResNet34.csv
# 45thResNet50500300_train_0.8_ver16epoch_17.csv
# 48th_EfficientNet_b7500300_train_0.7_v2epoch_3.csv
# 59th_VisionTransform350350_train_0.8epoch_2.csv
# 57th_EfficientNet_b4350350_train_0.8_ver22epoch_15.csv
# ##BEST3##28th_EfficientNet_b2oversample_size_500300_loss_label_weight_epoch_20.csv
# 35th_submission.csv
# 49th_EfficientNet_b4500300_train_0.7_augmentationepoch_12.csv
# 47thEfficientNet_b2400300_train_0.7_ver17epoch_8.csv
# 52th_EfficientNet_b4300300_train_0.4_ver19epoch_25.csv
# submission.csv
# submission_Inception_size224_19.csv
# 50th_Ensemble_ver3.csv
# 38th_EfficientNet_b2500300_train_0.8_ver10_pixblur.csv
# 40th_EfficientNet_b2500300_train_0.8_ver12_uniformdist_epoch_7.csv
# ...

# %%
model.fc
# Out:
# Linear(in_features=768, out_features=1000, bias=True)
